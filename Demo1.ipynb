# %%
# %run QDirac2.ipynb

# %%
qc = QuantumCircuit(3)
# Out:
# Initialize by <instance>.init()

# %%
qc.init()

# %%
qc.state_vector()
# Out:
# array([[1.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.]])

# %%
qc.X(2)

# %%
qc.state_vector()
# Out:
# array([[0.],
#        [1.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.]])

# %%
qc.CX(0, 1)

# %%
qc.state_vector()
# Out:
# array([[0.],
#        [1.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.]])

# %%
pitsianis_van_loan_rank_1(qc.state_vector(), 4, 1, 2, 1)
# Out:
# (array([[1.],
#         [0.],
#         [0.],
#         [0.]]),
#  array([[0.],
#         [1.]]))
